# %%
# Environment setup and module import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
def load_encoded_data(filename):
    data = pd.read_csv('data/'+filename+'_encoded.csv')
    if 'HasDetections' in data.columns:
        labels = pd.DataFrame(data['HasDetections']).values.reshape(len(data))
        data.drop(columns=['HasDetections'], inplace=True)
    else:
        labels=None
    return data, labels

# %%
print("loading mini train ...")
mini_train_data, mini_train_labels = load_encoded_data('mini_train')
print("loading mini dev ...")
mini_dev_data, mini_dev_labels = load_encoded_data('mini_dev')
print("loading mini test ...")
mini_test_data, mini_test_labels = load_encoded_data('mini_test')
# Out:
# loading mini train ...
# loading mini dev ...
# loading mini test ...

# %%
def find_correlations(data, labels):
    correlated_cols = []
    for i, col in enumerate(data.columns):
        if len(data[col].unique())>1:
            corr = np.corrcoef(data[col].values.reshape(len(labels)), labels)[0][1]
            correlated_cols.append([col, np.abs(corr), corr])
            
    return pd.DataFrame(correlated_cols, columns=['col', 'abscorr', 'corr']).sort_values('abscorr', ascending=False)

# %%
corr = find_correlations(mini_train_data, mini_train_labels)
display(corr)
corr_cols = corr['col'].values.reshape(len(corr))
# Out:
#                                     col   abscorr      corr
# 13                          SmartScreen  0.193585 -0.193585
# 103                 AVProductsInstalled  0.144179 -0.144179
# 123           AVProductStatesIdentifier  0.118651  0.118651
# 67                  OsBuildLab_platform  0.074611 -0.074611
# 7                             Processor  0.074339 -0.074339
# ..                                  ...       ...       ...
# 113  Census_OSInstallLanguageIdentifier  0.000499  0.000499
# 0                     MachineIdentifier  0.000450 -0.000450
# 75           Census_IsSecureBootEnabled  0.000421  0.000421
# 83          Census_OSUILocaleIdentifier  0.000375  0.000375
# 69                               IsBeta  0.000002  0.000002
#
# [143 rows x 3 columns]

# %%
def score_log_reg(train_data, train_labels, dev_data, dev_labels):
    lrc = LogisticRegression(solver='lbfgs', max_iter=150)
    lrc.fit(X=train_data, y=train_labels)

    # predict and score on the dev set
    pred = lrc.predict(dev_data)
    return metrics.accuracy_score(y_true=dev_labels, y_pred=pred)

# %%
def score_tree(train_data, train_labels, dev_data, dev_labels):
    dtc = DecisionTreeClassifier()
    dtc.fit(X=train_data, y=train_labels)

    # predict and score on the dev set
    pred = dtc.predict(dev_data)
    return metrics.accuracy_score(y_true=dev_labels, y_pred=pred)

# %%
print("using only top n correlated columns")
print("fitting and scoring logistic regressions ...")
print()

cols = []
best = 0
for n in range(1,139): 
    print(n, end=" ")
    print('adding column',corr_cols[n-1], '...', end=' ')
    cols.append(corr_cols[n-1])
    data = mini_train_data.filter(cols)
    dev_data = mini_dev_data.filter(cols)
    acc = score_tree(data, mini_train_labels, dev_data, mini_dev_labels)
    print('accuracy =', acc, end=" ")
    if acc > best:
        print("keeping this column")
        best = acc
    else:
        cols.remove(corr_cols[n-1])
        print()
        
print("cols_selected =[")
for col in cols:
    print('    \''+col+'\',')
print("]")
# Out:
# using only top n correlated columns
# fitting and scoring logistic regressions ...
#
# 1 adding column SmartScreen ... accuracy = 0.5760039455395973 keeping this column
# 2 adding column AVProductsInstalled ... accuracy = 0.5849262453109354 keeping this column
# 3 adding column AVProductStatesIdentifier ... accuracy = 0.5879302356862101 keeping this column
# 4 adding column OsBuildLab_platform ... accuracy = 0.5996024569951129 keeping this column
# 5 adding column Processor ... accuracy = 0.5996024569951129
# 6 adding column Census_OSArchitecture ... accuracy = 0.5995127856406272
# 7 adding column AppVersion_build1 ... accuracy = 0.6067612201282301 keeping this column
# 8 adding column Census_IsAlwaysOnAlwaysConnectedCapable ... accuracy = 0.6097801557292523 keeping this column
# 9 adding column EngineVersion_build2 ... accuracy = 0.6109757737890631 keeping this column
# 10 adding column IsProtected ... accuracy = 0.6109757737890631
# 11 adding column Census_TotalPhysicalRAM ... accuracy = 0.6113344592070064 keeping this column
# 12 adding column Census_ProcessorCoreCount ... accuracy = 0.6070601246431827
# 13 adding column Wdft_IsGamer ... accuracy = 0.6109309381118202
# 14 adding column AvSigVersion ... accuracy = 0.5741656827726382
# 15 adding column EngineVersion_build1 ... accuracy = 0.6110504999178012
# 16 adding column EngineVersion_combined ... accuracy = 0.6112597330782682
# 17 adding column Census_IsVirtualDevice ... accuracy = 0.6122760084291073 keeping this column
# 18 adding column EngineVersion ... accuracy = 0.6119023777854165
# 19 adding column AvSigVersion_minor ... accuracy = 0.6119322682369117
# 20 adding column Census_PowerPlatformRoleName ... accuracy = 0.6083005783802364
# 21 adding column Census_PrimaryDiskTotalCapacity ... accuracy = 0.6047735051037946
# 22 adding column AppVersion_minor ... accuracy = 0.6128140365560222 keeping this column
# 23 adding column AppVersion_combined ... accuracy = 0.6122311727518644
# 24 adding column Census_IsTouchEnabled ... accuracy = 0.6117379803021925
# 25 adding column RtpStateBitfield ... accuracy = 0.6129186531362556 keeping this column
# 26 adding column SMode_wasna ... accuracy = 0.6136958048751326 keeping this column
# 27 adding column IsSxsPassiveMode ... accuracy = 0.6139797641643377 keeping this column
# 28 adding column OsBuildLab_build1 ... accuracy = 0.6074785909641165
# 29 adding column AVProductsEnabled ... accuracy = 0.6142188877762998 keeping this column
# 30 adding column Census_InternalPrimaryDiagonalDisplaySizeInInches ... accuracy = 0.5972411113269865
# 31 adding column Census_OSVersion ... accuracy = 0.601321157956091
# 32 adding column Census_OSVersion_combined ... accuracy = 0.6113195139812587
# 33 adding column Census_OSVersion_build1 ... accuracy = 0.611140171272287
# 34 adding column Census_OSBuildNumber ... accuracy = 0.6113045687555111
# 35 adding column Census_InternalPrimaryDisplayResolutionHorizontal ... accuracy = 0.6042952578798703
# 36 adding column OsBuildLab_combined ... accuracy = 0.6070601246431827
# 37 adding column OsBuild ... accuracy = 0.6096008130202807
# 38 adding column OsBuildLab_major ... accuracy = 0.6099445532124763
# 39 adding column AppVersion ... accuracy = 0.6117828159794354
# 40 adding column Census_PrimaryDiskTypeName ... accuracy = 0.6100342245669621
# 41 adding column Census_OSSkuName ... accuracy = 0.6097203748262617
# 42 adding column Census_OSEdition ... accuracy = 0.6096456486975236
# 43 adding column Wdft_RegionIdentifier ... accuracy = 0.6065370417420155
# 44 adding column AppVersion_build2 ... accuracy = 0.6121564466231263
# 45 adding column Census_FirmwareManufacturerIdentifier_wasna ... accuracy = 0.6139349284870947
# 46 adding column Census_HasOpticalDiskDrive ... accuracy = 0.6120966657201357
# 47 adding column Census_ProcessorModelIdentifier ... accuracy = 0.5845675598929921
# 48 adding column AvSigVersion_build1 ... accuracy = 0.5732839144535278
# 49 adding column OsBuildLab_build2 ... accuracy = 0.6079867286395361
# 50 adding column Census_FirmwareManufacturerIdentifier ... accuracy = 0.6025167760159017
# 51 adding column Census_FirmwareVersionIdentifier_wasna ... accuracy = 0.6142487782277951 keeping this column
# 52 adding column OsSuite ... accuracy = 0.6107366501771009
# 53 adding column Census_IsPenCapable ... accuracy = 0.6145177922912526 keeping this column
# 54 adding column Census_ChassisTypeName ... accuracy = 0.6078970572850503
# 55 adding column Census_InternalBatteryNumberOfCharges ... accuracy = 0.6100192793412145
# 56 adding column DefaultBrowsersIdentifier_wasna ... accuracy = 0.6134417360374228
# 57 adding column Census_OSInstallTypeName ... accuracy = 0.6045792171690754
# 58 adding column Census_ActivationChannel ... accuracy = 0.609914662760981
# 59 adding column SkuEdition ... accuracy = 0.609630703471776
# 60 adding column DefaultBrowsersIdentifier ... accuracy = 0.612739310427284
# 61 adding column SMode ... accuracy = 0.6143085591307856
# 62 adding column Census_OEMNameIdentifier ... accuracy = 0.5968674806832958
# 63 adding column OsPlatformSubRelease ... accuracy = 0.6101836768244384
# 64 adding column LocaleEnglishNameIdentifier ... accuracy = 0.5958362601067089
# 65 adding column Census_InternalPrimaryDisplayResolutionVertical ... accuracy = 0.605655273422905
# 66 adding column OsBuildLab ... accuracy = 0.6071946316749115
# 67 adding column IsProtected_wasna ... accuracy = 0.6141889973248046
# 68 adding column Census_SystemVolumeTotalCapacity ... accuracy = 0.563778750878032
# 69 adding column AVProductsEnabled_wasna ... accuracy = 0.614502847065505
# 70 adding column AVProductStatesIdentifier_wasna ... accuracy = 0.6140843807445712
# 71 adding column AVProductsInstalled_wasna ... accuracy = 0.6140544902930759
# 72 adding column IeVerIdentifier ... accuracy = 0.6071796864491639
# 73 adding column AvSigVersion_combined ... accuracy = 0.5820119262901466
# 74 adding column Census_InternalBatteryNumberOfCharges_wasna ... accuracy = 0.6136061335206469
# 75 adding column Census_OSBuildRevision ... accuracy = 0.5982274962263305
# 76 adding column Census_OSVersion_build2 ... accuracy = 0.5981378248718446
# 77 adding column Census_IsFlightingInternal_wasna ... accuracy = 0.6119771039141546
# 78 adding column Census_IsWIMBootEnabled_wasna ... accuracy = 0.6105871979196246
# 79 adding column OsBuildLab_minor ... accuracy = 0.6064174799360345
# 80 adding column Census_ThresholdOptIn_wasna ... accuracy = 0.609959498438224
# 81 adding column Census_ProcessorModelIdentifier_wasna ... accuracy = 0.6140245998415806
# 82 adding column Census_ProcessorManufacturerIdentifier_wasna ... accuracy = 0.6140843807445712
# 83 adding column Census_ProcessorCoreCount_wasna ... accuracy = 0.6139050380355995
# 84 adding column Census_MDC2FormFactor ... accuracy = 0.6081511261227601
# 85 adding column Census_DeviceFamily ... accuracy = 0.6143832852595238
# 86 adding column Census_InternalBatteryType ... accuracy = 0.6085247567664509
# 87 adding column PuaMode ... accuracy = 0.6142188877762998
# 88 adding column Census_OSWUAutoUpdateOptionsName ... accuracy = 0.6080763999940219
# 89 adding column HasTpm ... accuracy = 0.6143384495822809
# 90 adding column RtpStateBitfield_wasna ... accuracy = 0.6145177922912526
# 91 adding column Wdft_IsGamer_wasna ... accuracy = 0.6153248344816249 keeping this column
# 92 adding column Wdft_RegionIdentifier_wasna ... accuracy = 0.6151753822241485
# 93 adding column Census_ProcessorClass ... accuracy = 0.6152650535786343
# 94 adding column Census_SystemVolumeTotalCapacity_wasna ... accuracy = 0.6150558204181674
# 95 adding column Census_PrimaryDiskTotalCapacity_wasna ... accuracy = 0.6154443962876059 keeping this column
# 96 adding column Census_IsAlwaysOnAlwaysConnectedCapable_wasna ... accuracy = 0.6152799988043819
# 97 adding column Census_OSBranch ... accuracy = 0.6095260868915425
# 98 adding column CountryIdentifier ... accuracy = 0.589693772324431
# 99 adding column Census_TotalPhysicalRAM_wasna ... accuracy = 0.6154443962876059
# 100 adding column ProductName ... accuracy = 0.6149213133864387
# 101 adding column Census_ProcessorManufacturerIdentifier ... accuracy = 0.6114540210129874
# 102 adding column Firewall ... accuracy = 0.6136210787463945
# 103 adding column CityIdentifier_wasna ... accuracy = 0.613680859649385
# 104 adding column Platform ... accuracy = 0.6149960395151769
# 105 adding column Census_OEMNameIdentifier_wasna ... accuracy = 0.6148316420319528
# 106 adding column Census_OEMModelIdentifier_wasna ... accuracy = 0.6143832852595238
# 107 adding column OsBuildLab_release ... accuracy = 0.6087190447011702
# 108 adding column OsVer_combined ... accuracy = 0.6151454917726532
# 109 adding column OsVer_major ... accuracy = 0.615235163127139
# 110 adding column GeoNameIdentifier ... accuracy = 0.5930713933433964
# 111 adding column OsVer_build1 ... accuracy = 0.6150408751924198
# 112 adding column UacLuaenable_wasna ... accuracy = 0.614741970677467
# 113 adding column OsVer ... accuracy = 0.6153098892558773
# 114 adding column GeoNameIdentifier_wasna ... accuracy = 0.6148914229349435
# 115 adding column Census_IsFlightsDisabled ... accuracy = 0.6146971350002242
# 116 adding column AvSigVersion_major ... accuracy = 0.6152501083528866
# 117 adding column Census_FlightRing ... accuracy = 0.6141591068733093
# 118 adding column Census_OSInstallLanguageIdentifier_wasna ... accuracy = 0.6150558204181674
# 119 adding column Census_IsPortableOperatingSystem ... accuracy = 0.6149960395151769
# 120 adding column Census_GenuineStateName ... accuracy = 0.6135314073919087
# 121 adding column OsVer_minor ... accuracy = 0.615115601321158
# 122 adding column Census_FirmwareVersionIdentifier ... accuracy = 0.569263648727414
# 123 adding column Census_OEMModelIdentifier ... accuracy = 0.577737591726323
# 124 adding column Census_IsFlightsDisabled_wasna ... accuracy = 0.6139498737128425
# 125 adding column CityIdentifier ... accuracy = 0.570040800466291
# 126 adding column Census_IsFlightingInternal ... accuracy = 0.6150259299666722
# 127 adding column UacLuaenable ... accuracy = 0.6144729566140097
# 128 adding column OsVer_build2 ... accuracy = 0.6151006560954103
# 129 adding column Firewall_wasna ... accuracy = 0.6150109847409245
# 130 adding column Census_IsVirtualDevice_wasna ... accuracy = 0.6154892319648488 keeping this column
# 131 adding column AutoSampleOptIn ... accuracy = 0.6148166968062052
# 132 adding column Census_ThresholdOptIn ... accuracy = 0.6152052726756437
# 133 adding column OrganizationIdentifier_wasna ... accuracy = 0.6094961964400473
# 134 adding column Census_InternalPrimaryDiagonalDisplaySizeInInches_wasna ... accuracy = 0.614622408871486
# 135 adding column IeVerIdentifier_wasna ... accuracy = 0.614502847065505
# 136 adding column Census_InternalPrimaryDisplayResolutionHorizontal_wasna ... accuracy = 0.6149661490636816
# 137 adding column Census_InternalPrimaryDisplayResolutionVertical_wasna ... accuracy = 0.6148017515804576
# 138 adding column OrganizationIdentifier ... accuracy = 0.6054908759396811
# cols_selected =[
#     'SmartScreen',
#     'AVProductsInstalled',
#     'AVProductStatesIdentifier',
#     'OsBuildLab_platform',
#     'AppVersion_build1',
#     'Census_IsAlwaysOnAlwaysConnectedCapable',
#     'EngineVersion_build2',
#     'Census_TotalPhysicalRAM',
#     'Census_IsVirtualDevice',
#     'AppVersion_minor',
#     'RtpStateBitfield',
#     'SMode_wasna',
#     'IsSxsPassiveMode',
#     'AVProductsEnabled',
#     'Census_FirmwareVersionIdentifier_wasna',
#     'Census_IsPenCapable',
#     'Wdft_IsGamer_wasna',
#     'Census_PrimaryDiskTotalCapacity_wasna',
#     'Census_IsVirtualDevice_wasna',
# ]

# %%
cols_selected =[
    'SmartScreen',
    'AVProductsInstalled',
    'AVProductStatesIdentifier',
    'OsBuildLab_platform',
    'AppVersion_build1',
    'Census_IsAlwaysOnAlwaysConnectedCapable',
    'EngineVersion_build2',
    'Census_TotalPhysicalRAM',
    'Census_IsVirtualDevice',
    'AppVersion_minor',
    'RtpStateBitfield',
    'SMode_wasna',
    'IsSxsPassiveMode',
    'AVProductsEnabled',
    'Census_FirmwareVersionIdentifier_wasna',
    'Census_IsPenCapable',
    'Wdft_IsGamer_wasna',
    'Census_PrimaryDiskTotalCapacity_wasna',
    'Census_IsVirtualDevice_wasna',
]

train_data_selected = mini_train_data.filter(cols_selected)
dev_data_selected = mini_dev_data.filter(cols_selected)
test_data_selected = mini_test_data.filter(cols_selected)

# %%
print('using decision tree with final selected columns ...', end=" ")
acc = score_tree(train_data_selected, mini_train_labels, dev_data_selected, mini_dev_labels)
print('accuracy on dev set =', round(100*acc,4), "% ")
# Out:
# using decision tree with final selected columns ... accuracy on dev set = 61.5385 %

# %%
acc = score_tree(train_data_selected, mini_train_labels, test_data_selected, mini_test_labels)
print('accuracy on test set =', round(100*acc,4), "% ")
# Out:
# accuracy on test set = 61.386 %

# %%
dtc = DecisionTreeClassifier()
cross_val_score(dtc, train_data_selected, mini_train_labels, cv=10, scoring='accuracy')
# Out:
# array([0.60923589, 0.61508407, 0.61396317, 0.61463571, 0.61617294,
#        0.6101201 , 0.6128743 , 0.61194556, 0.61072858, 0.6152442 ])
