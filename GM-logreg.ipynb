# %%
# Environment setup and module import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
def load_encoded_data(filename):
    data = pd.read_csv('data/'+filename+'_encoded.csv')
    if 'HasDetections' in data.columns:
        labels = pd.DataFrame(data['HasDetections']).values.reshape(len(data))
        data.drop(columns=['HasDetections'], inplace=True)
    else:
        labels=None
    return data, labels

# %%
print("loading mini train ...")
mini_train_data, mini_train_labels = load_encoded_data('mini_train')
print("loading mini dev ...")
mini_dev_data, mini_dev_labels = load_encoded_data('mini_dev')
print("loading mini test ...")
mini_test_data, mini_test_labels = load_encoded_data('mini_test')
# Out:
# loading mini train ...
# loading mini dev ...
# loading mini test ...

# %%
def find_correlations(data, labels):
    correlated_cols = []
    for i, col in enumerate(data.columns):
        if len(data[col].unique())>1:
            corr = np.corrcoef(data[col].values.reshape(len(labels)), labels)[0][1]
            correlated_cols.append([col, np.abs(corr), corr])
            
    return pd.DataFrame(correlated_cols, columns=['col', 'abscorr', 'corr']).sort_values('abscorr', ascending=False)

# %%
corr = find_correlations(mini_train_data, mini_train_labels)
display(corr)
corr_cols = corr['col'].values.reshape(len(corr))
# Out:
#                                                    col   abscorr      corr
# 67                                 AVProductsInstalled  0.144179 -0.144179
# 128                          AVProductStatesIdentifier  0.118651  0.118651
# 29                                 OsBuildLab_platform  0.074611 -0.074611
# 6                                            Processor  0.074339 -0.074339
# 20                               Census_OSArchitecture  0.074035 -0.074035
# 56                                   AppVersion_build1  0.073126 -0.073126
# 88             Census_IsAlwaysOnAlwaysConnectedCapable  0.061639 -0.061639
# 41                                EngineVersion_build2  0.061433 -0.061433
# 71                                         IsProtected  0.055379  0.055379
# 134                            Census_TotalPhysicalRAM  0.055017  0.055017
# 4                                         AvSigVersion  0.053625  0.053625
# 76                           Census_ProcessorCoreCount  0.052874  0.052874
# 89                                        Wdft_IsGamer  0.052003  0.052003
# 55                                EngineVersion_build1  0.051575  0.051575
# 87                              Census_IsVirtualDevice  0.050828 -0.050828
# 2                                        EngineVersion  0.049902  0.049902
# 58                                  AvSigVersion_minor  0.049705  0.049705
# 17                        Census_PowerPlatformRoleName  0.049683 -0.049683
# 132                    Census_PrimaryDiskTotalCapacity  0.045992  0.045992
# 42                                    AppVersion_minor  0.043533  0.043533
# 39                               Census_IsTouchEnabled  0.042238 -0.042238
# 100                                        SMode_wasna  0.041099 -0.041099
# 32                                    RtpStateBitfield  0.040893  0.040893
# 33                                    IsSxsPassiveMode  0.036238 -0.036238
# 65                                   OsBuildLab_build1  0.035602  0.035602
# 68                                   AVProductsEnabled  0.035312 -0.035312
# 79   Census_InternalPrimaryDiagonalDisplaySizeInInches  0.033172  0.033172
# 19                                    Census_OSVersion  0.032360  0.032360
# 60                             Census_OSVersion_build1  0.030395  0.030395
# 52                                Census_OSBuildNumber  0.030395  0.030395
# ..                                                 ...       ...       ...
# 7                                                OsVer  0.003990 -0.003990
# 98                             GeoNameIdentifier_wasna  0.003775 -0.003775
# 84                            Census_IsFlightsDisabled  0.003578 -0.003578
# 43                                  AvSigVersion_major  0.003578  0.003578
# 116           Census_OSInstallLanguageIdentifier_wasna  0.003228  0.003228
# 37                    Census_IsPortableOperatingSystem  0.003123  0.003123
# 26                             Census_GenuineStateName  0.003114  0.003114
# 0                                           Unnamed: 0  0.003048 -0.003048
# 45                                         OsVer_minor  0.003001 -0.003001
# 131                          Census_OEMModelIdentifier  0.002686 -0.002686
# 118                     Census_IsFlightsDisabled_wasna  0.002539  0.002539
# 129                                     CityIdentifier  0.001831 -0.001831
# 83                          Census_IsFlightingInternal  0.001790  0.001790
# 130                                       UacLuaenable  0.001790  0.001790
# 47                                        OsVer_build2  0.001789 -0.001789
# 102                                     Firewall_wasna  0.001675 -0.001675
# 122                       Census_IsVirtualDevice_wasna  0.001465  0.001465
# 35                                     AutoSampleOptIn  0.001036  0.001036
# 85                               Census_ThresholdOptIn  0.000993 -0.000993
# 97                        OrganizationIdentifier_wasna  0.000865  0.000865
# 112  Census_InternalPrimaryDiagonalDisplaySizeInInc...  0.000772  0.000772
# 101                              IeVerIdentifier_wasna  0.000762 -0.000762
# 113  Census_InternalPrimaryDisplayResolutionHorizon...  0.000729  0.000729
# 114  Census_InternalPrimaryDisplayResolutionVertica...  0.000729  0.000729
# 69                              OrganizationIdentifier  0.000581  0.000581
# 82                  Census_OSInstallLanguageIdentifier  0.000499  0.000499
# 38                          Census_IsSecureBootEnabled  0.000421  0.000421
# 54                         Census_OSUILocaleIdentifier  0.000375  0.000375
# 31                                              IsBeta  0.000002  0.000002
# 136                   Census_FirmwareVersionIdentifier       NaN       NaN
#
# [140 rows x 3 columns]

# %%
def score_log_reg(train_data, train_labels, dev_data, dev_labels):
    lrc = LogisticRegression(solver='lbfgs', max_iter=150)
    lrc.fit(X=train_data, y=train_labels)

    # predict and score on the dev set
    pred = lrc.predict(dev_data)
    return metrics.accuracy_score(y_true=dev_labels, y_pred=pred)

# %%
print("using only top n correlated columns")
print("fitting and scoring logistic regressions ...")
print()

cols = []
best = 0
for n in range(1,139): 
    print(n, end=" ")
    print('adding column',corr_cols[n-1], '...', end=' ')
    cols.append(corr_cols[n-1])
    data = mini_train_data.filter(cols)
    dev_data = mini_dev_data.filter(cols)
    acc = score_tree(data, mini_train_labels, dev_data, mini_dev_labels)
    print('accuracy =', acc, end=" ")
    if acc > best:
        print("keeping this column")
        best = acc
    else:
        cols.remove(corr_cols[n-1])
        print()
        
print("cols_selected =[")
for col in cols:
    print('    \''+col+'\',')
print("]")
# Out:
# using only top n correlated columns
# fitting and scoring logistic regressions ...
#
# 1 adding column AVProductsInstalled ... accuracy = 0.5660205347401772 keeping this column
# 2 adding column AVProductStatesIdentifier ... accuracy = 0.5682772638280701 keeping this column
# 3 adding column OsBuildLab_platform ... accuracy = 0.5796057449447773 keeping this column
# 4 adding column Processor ... accuracy = 0.5796505806220204 keeping this column
# 5 adding column Census_OSArchitecture ... accuracy = 0.5795011283645439
# 6 adding column AppVersion_build1 ... accuracy = 0.5686060587945181
# 7 adding column Census_IsAlwaysOnAlwaysConnectedCapable ... accuracy = 0.5815635695177176 keeping this column
# 8 adding column EngineVersion_build2 ... accuracy = 0.5867495628521469 keeping this column
# 9 adding column IsProtected ... accuracy = 0.5866897819491563
# 10 adding column Census_TotalPhysicalRAM ... accuracy = 0.49257969541629926
# 11 adding column AvSigVersion ... accuracy = 0.5185395525399411
# 12 adding column Census_ProcessorCoreCount ... accuracy = 0.5877060572999955 keeping this column
# 13 adding column Wdft_IsGamer ... accuracy = 0.5862563704024749
# 14 adding column EngineVersion_build1 ... accuracy = 0.5656917397737293
# 15 adding column Census_IsVirtualDevice ... accuracy = 0.5899478411621407 keeping this column
# 16 adding column EngineVersion ... accuracy = 0.4954192883083499
# 17 adding column AvSigVersion_minor ... accuracy = 0.5682324281508272
# 18 adding column Census_PowerPlatformRoleName ... accuracy = 0.587033522141352
# 19 adding column Census_PrimaryDiskTotalCapacity ... accuracy = 0.5583237434801452
# 20 adding column AppVersion_minor ... accuracy = 0.5906801572237749 keeping this column
# 21 adding column Census_IsTouchEnabled ... accuracy = 0.5905605954177938
# 22 adding column SMode_wasna ... accuracy = 0.5921298441212954 keeping this column
# 23 adding column RtpStateBitfield ... accuracy = 0.5921148988955478
# 24 adding column IsSxsPassiveMode ... accuracy = 0.5928920506344248 keeping this column
# 25 adding column OsBuildLab_build1 ... accuracy = 0.5896041009699452
# 26 adding column AVProductsEnabled ... accuracy = 0.5936243666960589 keeping this column
# 27 adding column Census_InternalPrimaryDiagonalDisplaySizeInInches ... accuracy = 0.5823706117080899
# 28 adding column Census_OSVersion ... accuracy = 0.5356368907952355
# 29 adding column Census_OSVersion_build1 ... accuracy = 0.5759740550881021
# 30 adding column Census_OSBuildNumber ... accuracy = 0.5478919759082961
# 31 adding column Census_OSVersion_combined ... accuracy = 0.5937289832762924 keeping this column
# 32 adding column Census_InternalPrimaryDisplayResolutionHorizontal ... accuracy = 0.5532124762744541
# 33 adding column Census_OSEdition ... accuracy = 0.5884533185873773
# 34 adding column OsBuildLab_combined ... accuracy = 0.5903663074830745
# 35 adding column OsBuild ... accuracy = 0.5679783593131175
# 36 adding column OsBuildLab_major ... accuracy = 0.568770456277742
# 37 adding column Census_OSSkuName ... accuracy = 0.5889614562627968
# 38 adding column Census_PrimaryDiskTypeName ... accuracy = 0.5923988581847529
# 39 adding column Wdft_RegionIdentifier ... accuracy = 0.5910238974159705
# 40 adding column AppVersion_build2 ... accuracy = 0.5737920521289475
# 41 adding column AppVersion ... accuracy = 0.5164771113867676
# 42 adding column Census_FirmwareManufacturerIdentifier_wasna ... accuracy = 0.5935645857930684
# 43 adding column Census_HasOpticalDiskDrive ... accuracy = 0.5917711587033522
# 44 adding column Census_ProcessorModelIdentifier ... accuracy = 0.5681726472478367
# 45 adding column AvSigVersion_build1 ... accuracy = 0.550148704996189
# 46 adding column OsBuildLab_build2 ... accuracy = 0.5647800810031236
# 47 adding column Census_FirmwareManufacturerIdentifier ... accuracy = 0.5856585613725696
# 48 adding column OsSuite ... accuracy = 0.5888568396825634
# 49 adding column Census_IsPenCapable ... accuracy = 0.5935048048900778
# 50 adding column Census_InternalBatteryNumberOfCharges ... accuracy = 0.5638983126840131
# 51 adding column Census_ChassisTypeName ... accuracy = 0.559564197217199
# 52 adding column DefaultBrowsersIdentifier_wasna ... accuracy = 0.5928322697314343
# 53 adding column Census_OSInstallTypeName ... accuracy = 0.5880199070406958
# 54 adding column Census_ActivationChannel ... accuracy = 0.5920700632183049
# 55 adding column SkuEdition ... accuracy = 0.5920102823153144
# 56 adding column DefaultBrowsersIdentifier ... accuracy = 0.5917412682518569
# 57 adding column SMode ... accuracy = 0.5938784355337687 keeping this column
# 58 adding column Census_OEMNameIdentifier ... accuracy = 0.583222489575705
# 59 adding column OsPlatformSubRelease ... accuracy = 0.5924436938619958
# 60 adding column OsBuildLab ... accuracy = 0.5346953415731345
# 61 adding column LocaleEnglishNameIdentifier ... accuracy = 0.5696372793711049
# 62 adding column Census_InternalPrimaryDisplayResolutionVertical ... accuracy = 0.5618358715308395
# 63 adding column IsProtected_wasna ... accuracy = 0.5938335998565258
# 64 adding column Census_SystemVolumeTotalCapacity ... accuracy = 0.5363243711796266
# 65 adding column AVProductsEnabled_wasna ... accuracy = 0.5938335998565258
# 66 adding column AVProductStatesIdentifier_wasna ... accuracy = 0.5934450239870873
# 67 adding column AVProductsInstalled_wasna ... accuracy = 0.5936542571475543
# 68 adding column IeVerIdentifier ... accuracy = 0.5903663074830745
# 69 adding column OsBuildLab_release ... accuracy = 0.5913825828339138
# 70 adding column Census_InternalBatteryNumberOfCharges_wasna ... accuracy = 0.5924885295392387
# 71 adding column Census_OSVersion_build2 ... accuracy = 0.5582789078029023
# 72 adding column Census_OSBuildRevision ... accuracy = 0.5607299248255145
# 73 adding column Census_InternalBatteryType ... accuracy = 0.5568441661311294
# 74 adding column Census_IsFlightingInternal_wasna ... accuracy = 0.5906054310950367
# 75 adding column Census_IsWIMBootEnabled_wasna ... accuracy = 0.5905008145148033
# 76 adding column OsBuildLab_minor ... accuracy = 0.5578604414819686
# 77 adding column Census_ThresholdOptIn_wasna ... accuracy = 0.5904858692890557
# 78 adding column Census_ProcessorModelIdentifier_wasna ... accuracy = 0.5936841475990495
# 79 adding column Census_ProcessorManufacturerIdentifier_wasna ... accuracy = 0.5937738189535353
# 80 adding column Census_ProcessorCoreCount_wasna ... accuracy = 0.59374392850204
# 81 adding column Census_OSBranch ... accuracy = 0.5907399381267654
# 82 adding column Census_MDC2FormFactor ... accuracy = 0.5904410336118127
# 83 adding column Census_DeviceFamily ... accuracy = 0.5934001883098444
# 84 adding column PuaMode ... accuracy = 0.5935048048900778
# 85 adding column Census_OSWUAutoUpdateOptionsName ... accuracy = 0.5891557441975162
# 86 adding column HasTpm ... accuracy = 0.5937588737277877
# 87 adding column RtpStateBitfield_wasna ... accuracy = 0.5938784355337687
# 88 adding column Wdft_IsGamer_wasna ... accuracy = 0.5949395465618508 keeping this column
# 89 adding column Wdft_RegionIdentifier_wasna ... accuracy = 0.5951188892708225 keeping this column
# 90 adding column Census_ProcessorClass ... accuracy = 0.5949395465618508
# 91 adding column Census_SystemVolumeTotalCapacity_wasna ... accuracy = 0.5947153681756363
# 92 adding column Census_PrimaryDiskTotalCapacity_wasna ... accuracy = 0.5951487797223177 keeping this column
# 93 adding column Census_IsAlwaysOnAlwaysConnectedCapable_wasna ... accuracy = 0.5946107515954029
# 94 adding column AvSigVersion_combined ... accuracy = 0.5984666198382926 keeping this column
# 95 adding column Census_FlightRing ... accuracy = 0.5964340691366143
# 96 adding column CountryIdentifier ... accuracy = 0.5620301594655587
# 97 adding column Census_TotalPhysicalRAM_wasna ... accuracy = 0.5980481535173588
# 98 adding column ProductName ... accuracy = 0.5941922852744691
# 99 adding column Census_ProcessorManufacturerIdentifier ... accuracy = 0.5960454932671758
# 100 adding column AppVersion_combined ... accuracy = 0.5981527700975924
# 101 adding column Firewall ... accuracy = 0.5982424414520782
# 102 adding column CityIdentifier_wasna ... accuracy = 0.5967180284258193
# 103 adding column Platform ... accuracy = 0.5984068389353021
# 104 adding column Census_OEMNameIdentifier_wasna ... accuracy = 0.5982424414520782
# 105 adding column Census_OEMModelIdentifier_wasna ... accuracy = 0.5975848515191822
# 106 adding column OsVer_combined ... accuracy = 0.5985114555155355 keeping this column
# 107 adding column OsVer_major ... accuracy = 0.5985562911927784 keeping this column
# 108 adding column GeoNameIdentifier ... accuracy = 0.579949485136973
# 109 adding column OsVer_build1 ... accuracy = 0.5981826605490876
# 110 adding column UacLuaenable_wasna ... accuracy = 0.5979435369371254
# 111 adding column OsVer ... accuracy = 0.5983171675808163
# 112 adding column GeoNameIdentifier_wasna ... accuracy = 0.5984666198382926
# 113 adding column Census_IsFlightsDisabled ... accuracy = 0.5986011268700214 keeping this column
# 114 adding column AvSigVersion_major ... accuracy = 0.5985114555155355
# 115 adding column Census_OSInstallLanguageIdentifier_wasna ... accuracy = 0.5978837560341349
# 116 adding column Census_IsPortableOperatingSystem ... accuracy = 0.5986011268700214
# 117 adding column Census_GenuineStateName ... accuracy = 0.5972710017784819
# 118 adding column Unnamed: 0 ... accuracy = 0.5349793008623396
# 119 adding column OsVer_minor ... accuracy = 0.5987206886760025 keeping this column
# 120 adding column Census_OEMModelIdentifier ... accuracy = 0.5429301609600813
# 121 adding column Census_IsFlightsDisabled_wasna ... accuracy = 0.5980780439688541
# 122 adding column CityIdentifier ... accuracy = 0.5350689722168254
# 123 adding column Census_IsFlightingInternal ... accuracy = 0.5985562911927784
# 124 adding column UacLuaenable ... accuracy = 0.5988402504819835 keeping this column
# 125 adding column OsVer_build2 ... accuracy = 0.5984815650640403
# 126 adding column Firewall_wasna ... accuracy = 0.5988701409334788 keeping this column
# 127 adding column Census_IsVirtualDevice_wasna ... accuracy = 0.598451674612545
# 128 adding column AutoSampleOptIn ... accuracy = 0.5986011268700214
# 129 adding column Census_ThresholdOptIn ... accuracy = 0.5984068389353021
# 130 adding column OrganizationIdentifier_wasna ... accuracy = 0.593415133535592
# 131 adding column Census_InternalPrimaryDiagonalDisplaySizeInInches_wasna ... accuracy = 0.5981079344203494
# 132 adding column IeVerIdentifier_wasna ... accuracy = 0.598332112806564
# 133 adding column Census_InternalPrimaryDisplayResolutionHorizontal_wasna ... accuracy = 0.5986907982245072
# 134 adding column Census_InternalPrimaryDisplayResolutionVertical_wasna ... accuracy = 0.5983918937095545
# 135 adding column OrganizationIdentifier ... accuracy = 0.5904858692890557
# 136 adding column Census_OSInstallLanguageIdentifier ... accuracy = 0.58875222310233
# 137 adding column Census_IsSecureBootEnabled ... accuracy = 0.5931760099236298
# 138 adding column Census_OSUILocaleIdentifier ... accuracy = 0.5784549625622095
# cols_selected =[
#     'AVProductsInstalled',
#     'AVProductStatesIdentifier',
#     'OsBuildLab_platform',
#     'Processor',
#     'Census_IsAlwaysOnAlwaysConnectedCapable',
#     'EngineVersion_build2',
#     'Census_ProcessorCoreCount',
#     'Census_IsVirtualDevice',
#     'AppVersion_minor',
#     'SMode_wasna',
#     'IsSxsPassiveMode',
#     'AVProductsEnabled',
#     'Census_OSVersion_combined',
#     'SMode',
#     'Wdft_IsGamer_wasna',
#     'Wdft_RegionIdentifier_wasna',
#     'Census_PrimaryDiskTotalCapacity_wasna',
#     'AvSigVersion_combined',
#     'OsVer_combined',
#     'OsVer_major',
#     'Census_IsFlightsDisabled',
#     'OsVer_minor',
#     'UacLuaenable',
#     'Firewall_wasna',
# ]

# %%
cols_selected =[
    'AVProductsInstalled',
    'AVProductStatesIdentifier',
    'OsBuildLab_platform',
    'Census_IsAlwaysOnAlwaysConnectedCapable',
    'EngineVersion_build2',
    'Census_ProcessorCoreCount',
    'Census_IsVirtualDevice',
    'AppVersion_minor',
    'Census_IsTouchEnabled',
    'SMode_wasna',
#     'RtpStateBitfield',
#     'AVProductsEnabled',
#     'AVProductsEnabled_wasna',
#     'RtpStateBitfield_wasna',
#     'Wdft_IsGamer_wasna',
#     'Census_IsAlwaysOnAlwaysConnectedCapable_wasna',
#     'AvSigVersion_combined',
#     'AppVersion_combined',
#     'Platform',
#     'Census_IsPortableOperatingSystem',
#     'OsVer_minor',
#     'UacLuaenable',
#     'Census_IsVirtualDevice_wasna',
#     'Census_InternalPrimaryDisplayResolutionHorizontal_wasna',
]


train_data_selected = mini_train_data.filter(cols_selected)
dev_data_selected = mini_dev_data.filter(cols_selected)
test_data_selected = mini_test_data.filter(cols_selected)

# %%
def score_tree(train_data, train_labels, dev_data, dev_labels):
    dtc = DecisionTreeClassifier()
    dtc.fit(X=train_data, y=train_labels)

    # predict and score on the dev set
    pred = dtc.predict(dev_data)
    return metrics.accuracy_score(y_true=dev_labels, y_pred=pred)

# %%
print('using decision tree with final selected columns ...', end=" ")
acc = score_tree(train_data_selected, mini_train_labels, dev_data_selected, mini_dev_labels)
print('accuracy on dev set =', round(100*acc,4), "% ")
# Out:
# using decision tree with final selected columns ... accuracy on dev set = 59.1517 %

# %%
acc = score_tree(train_data_selected, mini_train_labels, test_data_selected, mini_test_labels)
print('accuracy on test set =', round(100*acc,4), "% ")
# Out:
# accuracy on test set = 59.9453 %

# %%
dtc = DecisionTreeClassifier()
cross_val_score(dtc, train_data_selected, mini_train_labels, cv=2, scoring='accuracy')
# Out:
# array([0.59999616, 0.59711129])
